# %% [markdown]
# # assignment

# %%
from bs4 import BeautifulSoup

# %%
import requests

# %%
url="https://www.flipkart.com/search?q=moto&otracker=search&otracker1=search&marketplace=FLIPKART&as-show=on&as=off"

# %%
respones=requests.get(url)

# %%
respones
# Out:
# <Response [200]>

# %%
moto=BeautifulSoup(respones.text)

# %%
moto
# Out:
# <!DOCTYPE html>
# ...

# %%
mobname=moto.select("._4rR01T")

# %%
mobname
# Out:
# [<div class="_4rR01T">MOTOROLA e13 (Aurora Green, 64 GB)</div>,
#  <div class="_4rR01T">MOTOROLA e40 (Carbon Gray, 64 GB)</div>,
#  <div class="_4rR01T">MOTOROLA G62 5G (Frosted Blue, 128 GB)</div>,
#  <div class="_4rR01T">MOTOROLA g52 (Charcoal Grey, 64 GB)</div>,
#  <div class="_4rR01T">MOTOROLA g52 (Charcoal Grey, 128 GB)</div>,
#  <div class="_4rR01T">MOTOROLA G32 (Mineral Gray, 128 GB)</div>,
#  <div class="_4rR01T">MOTOROLA g31 (Baby Blue, 128 GB)</div>,
#  <div class="_4rR01T">MOTOROLA g52 (Metallic White, 128 GB)</div>,
#  <div class="_4rR01T">MOTOROLA G32 (Satin Silver, 128 GB)</div>,
#  <div class="_4rR01T">MOTOROLA g31 (Meteorite Grey, 64 GB)</div>,
#  <div class="_4rR01T">MOTOROLA G62 5G (Midnight Gray, 128 GB)</div>,
#  <div class="_4rR01T">MOTOROLA e13 (Cosmic Black, 64 GB)</div>,
#  <div class="_4rR01T">MOTOROLA e13 (Creamy White, 64 GB)</div>,
#  <div class="_4rR01T">MOTOROLA G32 (Mineral Gray, 64 GB)</div>,
# ...

# %%
mobname_rating=moto.select("._1lRcqv ._3LWZlK")

# %%
mobname_rating
# Out:
# [<div class="_3LWZlK">4<img class="_1wB99o" src="..."/></div>,
#  <div class="_3LWZlK">4.2<img class="_1wB99o" src="..."/></div>,
#  <div class="_3LWZlK">4.2<img class="_1wB99o" src="..."/></div>,
#  <div class="_3LWZlK">4.2<img class="_1wB99o" src="..."/></div>,
#  <div class="_3LWZlK">4.2<img class="_1wB99o" src="..."/></div>,
#  <div class="_3LWZlK">4.2<img class="_1wB99o" src="..."/></div>,
#  <div class="_3LWZlK">4.1<img class="_1wB99o" src="..."/></div>,
#  <div class="_3LWZlK">4.2<img class="_1wB99o" src="..."/></div>,
#  <div class="_3LWZlK">4.2<img class="_1wB99o" src="..."/></div>,
#  <div class="_3LWZlK">4.1<img class="_1wB99o" src="..."/></div>,
#  <div class="_3LWZlK">4.2<img class="_1wB99o" src="..."/></div>,
#  <div class="_3LWZlK">4<img class="_1wB99o" src="..."/></div>,
#  <div class="_3LWZlK">4<img class="_1wB99o" src="..."/></div>,
#  <div class="_3LWZlK">4.2<img class="_1wB99o" src="..."/></div>,
#  <div class="_3LWZlK">4.1<img class="_1wB99o" src="..."/></div>,
# ...

# %%
mobname_price=moto.select("._1_WHN1")

# %%
mobname_price
# Out:
# [<div class="_30jeq3 _1_WHN1">₹7,749</div>,
#  <div class="_30jeq3 _1_WHN1">₹8,499</div>,
#  <div class="_30jeq3 _1_WHN1">₹15,499</div>,
#  <div class="_30jeq3 _1_WHN1">₹10,999</div>,
#  <div class="_30jeq3 _1_WHN1">₹13,999</div>,
#  <div class="_30jeq3 _1_WHN1">₹11,999</div>,
#  <div class="_30jeq3 _1_WHN1">₹10,999</div>,
#  <div class="_30jeq3 _1_WHN1">₹13,999</div>,
#  <div class="_30jeq3 _1_WHN1">₹11,999</div>,
#  <div class="_30jeq3 _1_WHN1">₹16,499</div>,
#  <div class="_30jeq3 _1_WHN1">₹9,499</div>,
#  <div class="_30jeq3 _1_WHN1">₹7,749</div>,
#  <div class="_30jeq3 _1_WHN1">₹7,749</div>,
#  <div class="_30jeq3 _1_WHN1">₹10,499</div>,
#  <div class="_30jeq3 _1_WHN1">₹14,999</div>,
#  <div class="_30jeq3 _1_WHN1">₹14,999</div>,
#  <div class="_30jeq3 _1_WHN1">₹16,499</div>,
#  <div class="_30jeq3 _1_WHN1">₹18,999</div>,
#  <div class="_30jeq3 _1_WHN1">₹9,499</div>,
#  <div class="_30jeq3 _1_WHN1">₹15,499</div>,
#  <div class="_30jeq3 _1_WHN1">₹18,999</div>,
# ...

# %%
import pandas as pds

# %%
mobname=pds.DataFrame({'mobiles':mobname,'rating':mobname_rating,'price':mobname_price})

# %%
mobname
# Out:
#                                         mobiles     rating      price
# 0          [MOTOROLA e13 (Aurora Green, 64 GB)]    [4, []]   [₹7,749]
# 1           [MOTOROLA e40 (Carbon Gray, 64 GB)]  [4.2, []]   [₹8,499]
# 2      [MOTOROLA G62 5G (Frosted Blue, 128 GB)]  [4.2, []]  [₹15,499]
# 3         [MOTOROLA g52 (Charcoal Grey, 64 GB)]  [4.2, []]  [₹10,999]
# 4        [MOTOROLA g52 (Charcoal Grey, 128 GB)]  [4.2, []]  [₹13,999]
# 5         [MOTOROLA G32 (Mineral Gray, 128 GB)]  [4.2, []]  [₹11,999]
# 6            [MOTOROLA g31 (Baby Blue, 128 GB)]  [4.1, []]  [₹10,999]
# 7       [MOTOROLA g52 (Metallic White, 128 GB)]  [4.2, []]  [₹13,999]
# 8         [MOTOROLA G32 (Satin Silver, 128 GB)]  [4.2, []]  [₹11,999]
# 9     [MOTOROLA G62 5G (Midnight Gray, 128 GB)]  [4.1, []]  [₹16,499]
# 10       [MOTOROLA g31 (Meteorite Grey, 64 GB)]  [4.2, []]   [₹9,499]
# 11         [MOTOROLA e13 (Cosmic Black, 64 GB)]    [4, []]   [₹7,749]
# ...

# %%
d=mobname.to_csv('C:/arun/mobiles.csv')

# %%
file=pds.read_csv('C:/arun/mobiles.csv')

# %%
file
# Out:
#     Unnamed: 0                                            mobiles  \
# 0            0  <div class="_4rR01T">MOTOROLA e13 (Aurora Gree...
# 1            1  <div class="_4rR01T">MOTOROLA e40 (Carbon Gray...
# 2            2  <div class="_4rR01T">MOTOROLA G62 5G (Frosted ...
# 3            3  <div class="_4rR01T">MOTOROLA g52 (Charcoal Gr...
# 4            4  <div class="_4rR01T">MOTOROLA g52 (Charcoal Gr...
# 5            5  <div class="_4rR01T">MOTOROLA G32 (Mineral Gra...
# 6            6  <div class="_4rR01T">MOTOROLA g31 (Baby Blue, ...
# 7            7  <div class="_4rR01T">MOTOROLA g52 (Metallic Wh...
# 8            8  <div class="_4rR01T">MOTOROLA G32 (Satin Silve...
# 9            9  <div class="_4rR01T">MOTOROLA G62 5G (Midnight...
# 10          10  <div class="_4rR01T">MOTOROLA g31 (Meteorite G...
# 11          11  <div class="_4rR01T">MOTOROLA e13 (Cosmic Blac...
# 12          12  <div class="_4rR01T">MOTOROLA e13 (Creamy Whit...
# ...

# %%
edit=file["mobiles"]

# %%
edit
# Out:
# 0     <div class="_4rR01T">MOTOROLA e13 (Aurora Gree...
# 1     <div class="_4rR01T">MOTOROLA e40 (Carbon Gray...
# 2     <div class="_4rR01T">MOTOROLA G62 5G (Frosted ...
# 3     <div class="_4rR01T">MOTOROLA g52 (Charcoal Gr...
# 4     <div class="_4rR01T">MOTOROLA g52 (Charcoal Gr...
# 5     <div class="_4rR01T">MOTOROLA G32 (Mineral Gra...
# 6     <div class="_4rR01T">MOTOROLA g31 (Baby Blue, ...
# 7     <div class="_4rR01T">MOTOROLA g52 (Metallic Wh...
# 8     <div class="_4rR01T">MOTOROLA G32 (Satin Silve...
# 9     <div class="_4rR01T">MOTOROLA G62 5G (Midnight...
# 10    <div class="_4rR01T">MOTOROLA g31 (Meteorite G...
# 11    <div class="_4rR01T">MOTOROLA e13 (Cosmic Blac...
# 12    <div class="_4rR01T">MOTOROLA e13 (Creamy Whit...
# 13    <div class="_4rR01T">MOTOROLA G32 (Mineral Gra...
# 14    <div class="_4rR01T">MOTOROLA g72 (Polar Blue,...
# 15    <div class="_4rR01T">MOTOROLA g72 (Meteorite G...
# 16    <div class="_4rR01T">MOTOROLA G62 5G (Frosted ...
# ...

# %%
edit=edit.str.strip(' <div class="_4rR01T">').astype(str)

# %%
edit
# Out:
# 0            MOTOROLA e13 (Aurora Green, 64 GB)</
# 1             MOTOROLA e40 (Carbon Gray, 64 GB)</
# 2        MOTOROLA G62 5G (Frosted Blue, 128 GB)</
# 3           MOTOROLA g52 (Charcoal Grey, 64 GB)</
# 4          MOTOROLA g52 (Charcoal Grey, 128 GB)</
# 5           MOTOROLA G32 (Mineral Gray, 128 GB)</
# 6              MOTOROLA g31 (Baby Blue, 128 GB)</
# 7         MOTOROLA g52 (Metallic White, 128 GB)</
# 8           MOTOROLA G32 (Satin Silver, 128 GB)</
# 9       MOTOROLA G62 5G (Midnight Gray, 128 GB)</
# 10         MOTOROLA g31 (Meteorite Grey, 64 GB)</
# 11           MOTOROLA e13 (Cosmic Black, 64 GB)</
# 12           MOTOROLA e13 (Creamy White, 64 GB)</
# 13           MOTOROLA G32 (Mineral Gray, 64 GB)</
# 14            MOTOROLA g72 (Polar Blue, 128 GB)</
# 15        MOTOROLA g72 (Meteorite Grey, 128 GB)</
# 16       MOTOROLA G62 5G (Frosted Blue, 128 GB)</
# 17      MOTOROLA g73 5G (Midnight Blue, 128 GB)</
# 18           MOTOROLA g22 (Cosmic Black, 64 GB)</
# ...
